# %% [markdown]
# # Topics
# - make_pipeline
# - StratifiedKFold
# - cross_val_score
# - learning_curve
# - LearningCurveDisplay
# - validation_curve
# - GridSearchCV
#
# - confusion_matrix, ConfusionMatrixDisplay
# - precision_score, recall_score, f1_score, make_scorer
# - roc_curve, roc_auc_score, auc
#
# ---

# %% [markdown]
# ### Step 1: Import Packages

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

import tensorflow as tf

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2: Load the data

# %%
df = pd.read_csv(
     'https://archive.ics.uci.edu/ml/'
     'machine-learning-databases'
     '/breast-cancer-wisconsin/wdbc.data',
     header=None)

# %%
df.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Step 3: Preprocessing

# %% [markdown]
# ##### Split data to features and output and LabelEncoder output

# %%
# split data to feature and outcome
X = df.loc[:,2:].values
y = df.loc[:,1].values

# LabelEncoder output - change from string to numberical
le = LabelEncoder()
y = le.fit_transform(y)

print(f'label classes: {le.classes_}')
print(f'test the mapping: (M,B) {le.transform(['M','B'])}')
# Out:
# label classes: ['B' 'M']
# test the mapping: (M,B) [1 0]

# %% [markdown]
# ### Step 4: Split data to training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2,
    stratify=y, # keep the samle balance before split
    random_state=1
)

# %% [markdown]
# ### Step 5: Combining transformers and estimators in a pipeline

# %%
# create pipeline
pipe_lr = make_pipeline(StandardScaler(), # standardlize the data
                        PCA(n_components=2), # PCA reduces the dimentions to 2
                        LogisticRegression(random_state=1, solver='lbfgs')) # apply the LogisticRegression

# %%
# fit training data
pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=2)),
#                 ('logisticregression', LogisticRegression(random_state=1))])

# %%
# predict and test accuracy
y_pred = pipe_lr.predict(X_test)
print('Test Accuracy: %.3f' % pipe_lr.score(X_test, y_test)) # use X_test, y_test
# Out:
# Test Accuracy: 0.956

# %% [markdown]
# ### Step 6: Using k-fold cross-validation to assess model performance

# %% [markdown]
# ##### 1) StratifiedKFold: test accuracy on test data

# %%
# StratifedKFold will keep the propotion of Classes in train and test
from sklearn.model_selection import StratifiedKFold, cross_val_score

# applit StratifiedKFold, split data to 10 pieces, 9 used for train, 1 used for test
# StratifiedKFold is iterable dataset, with the index for train and test
kfold = StratifiedKFold(n_splits=10).split(X_train, y_train)
scores = []

# iterate over the StratifiedKFold
for idx, (train_idx, test_idx) in enumerate(kfold):
    pipe_lr.fit(X_train[train_idx], y_train[train_idx]) # use training index for training
    score = pipe_lr.score(X_train[test_idx], y_train[test_idx]) # use testing index for test score
    scores.append(score)
    # np.bincount() only apply to positive data, and return a list of counts
    print(f'Fold: {idx+1}, {np.bincount(y_train[train_idx])}, accuracy: {score:.4f}')
# Out:
# Fold: 1, [256 153], accurace: 0.9348
# Fold: 2, [256 153], accurace: 0.9348
# Fold: 3, [256 153], accurace: 0.9565
# Fold: 4, [256 153], accurace: 0.9565
# Fold: 5, [256 153], accurace: 0.9348
# Fold: 6, [257 153], accurace: 0.9556
# Fold: 7, [257 153], accurace: 0.9778
# Fold: 8, [257 153], accurace: 0.9333
# Fold: 9, [257 153], accurace: 0.9556
# Fold: 10, [257 153], accurace: 0.9556

# %% [markdown]
# ##### 2) cross_val_score: accuracy on the test data

# %%
# import the cross_val_score package
from sklearn.model_selection import cross_val_score

# apply the cross_val_score to the training dataset
scores = cross_val_score(
    estimator=pipe_lr, # model
    X = X_train,
    y = y_train,
    cv = 10, # split data to 10 folds
    n_jobs=1 # only use 1 CPU
)

# print all scores
print('CV accuracy scores: %s' % scores) 

# print the range
print('CV accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
# Out:
# CV accuracy scores: [0.93478261 0.93478261 0.95652174 0.95652174 0.93478261 0.95555556
#  0.97777778 0.93333333 0.95555556 0.95555556]
# CV accuracy: 0.950 +/- 0.014

# %% [markdown]
# ``cross_val_score``
# - returns a 1D NumPy array of scores, one per fold.
# - by default that's the estimators method - R^2 for regressors, accuracy for classifiers.
# - scoring='neg_mean_squared_error'; 'r2','roc_auc': 'neg_' prefix on error comback as negated, because Sklearn follows the convention that higher is better.
# - cross_val_score(model, X, y, scoring='')
# - the typical pattern is to report scores.mean() and scores.std() to capture both central performance and variance across folds.

# %% [markdown]
# ### Step 7: Diagnosing bias and variance problems with learning curves

# %% [markdown]
# ### Learning Curve

# %% [markdown]
# A learning curve is a diagnostic tool used in machine learning to plot the relationship between the number of training samples used and the model's performance (error or accuracy). It helps identify whether a model is suffering from high bias (underfitting) or high variance (overfitting).
#
# ``learning_curve answers one specific question``: how does model performance change as you give it more training data? It's the standard tool for diagnosing whether a model is suffering from high bias (underfitting) or high variance (overfitting).
# Here's the mechanism. You give it a list of training-set sizes via train_sizes. For each size, it does the following:
#
# - Carves out a fraction of the data of that size for training.
# - Fits the estimator on that subset.
# - Scores it twice — once on the training subset itself (training score) and once on a held-out validation fold (validation/test score).
# - Repeats this across cv folds and collects all the scores.

# %%
from sklearn.model_selection import learning_curve, LearningCurveDisplay

# %% [markdown]
# ##### First way - learning curve

# %%
from sklearn.model_selection import learning_curve
pipe_lr = make_pipeline(StandardScaler(),
                        LogisticRegression(
                                           random_state=1,
                                           solver='lbfgs',
                                           max_iter=10000))

# cv=10, train 10 times per split, so train_score has 10 values per split
train_sizes, train_score, test_score = learning_curve(
    estimator = pipe_lr,
    X = X_train, 
    y = y_train,
    cv = 10,
    train_sizes=np.linspace(0.1, 1, 10), # train size increase from low to high
    n_jobs=1
)

train_mean = train_score.mean(axis=1)
train_std = train_score.std(axis=1)
test_mean = test_score.mean(axis=1)
test_std = test_score.std(axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o',
         markersize=5, label='Training accuracy')
plt.fill_between(train_sizes,
                 train_mean + train_std,   # y1 — upper edge
                 train_mean - train_std,   # y2 — lower edge
                 alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean, color='green', marker='*',
         markersize=5, label='test accuracy')
plt.fill_between(train_sizes,
                 test_mean + test_std,   # y1 — upper edge
                 test_mean - test_std,   # y2 — lower edge
                 alpha=0.15, color='green')

plt.grid()
plt.xlabel('Number of training examples')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.8, 1.03])
plt.show()

# %% [markdown]
# ##### Second way - learning curve

# %%
LearningCurveDisplay.from_estimator(
    pipe_lr,
    X=X_train,
    y=y_train,
    train_sizes=np.linspace(0.1,1.0, 10),
    cv=10,
    n_jobs=-1,
    scoring='accuracy' # y_axis name
)
plt.grid()
plt.ylim([0.8, 1.03])
# Out:
# (0.8, 1.03)

# %% [markdown]
# ### validation_curve
# - A validation curve is a **diagnostic tool used to find the optimal hyperparameter for a model**. While a learning curve plots performance against the number of training samples, a validation curve plots performance against a single hyperparameter's value.
#
# - Purpose:
#     - The goal is to see how changing a specific hyperparameter affects the model's ability to generalize. it helps you identify the 'sweet spot' where the model is complex enough to learn the patterns but not so complext that it overfits.
# - Interpreting the Curves:
#     - Underfitting (High Bias): Both the training and validation scores are low. Changing the hyperparameter (e.g., increasing complexity) will cause both scores to rise together.
#     - Overfitting (High Variance): The training score is very high, but the validation score is low or starts decreasing. This indicates the hyperparameter is making the model too complex.
#     - Optimal Point: The point where the validation score is at its maximum before it begins to diverge from the training score.

# %%
from sklearn.model_selection import validation_curve
pipe_lr = make_pipeline(StandardScaler(),
                        LogisticRegression(
                                           random_state=1,
                                           solver='lbfgs',
                                           max_iter=10000))

param_range=[0.001, 0.01, 0.1, 1.10, 100.0]
# cv=10, train 10 times per split, so train_score has 10 values per split
train_score, test_score = validation_curve(
    estimator = pipe_lr,
    X = X_train, 
    y = y_train,
    cv = 10,
    param_name = 'logisticregression__C', # <step_name>__<parameter_name>
    param_range=param_range
)

train_mean = train_score.mean(axis=1)
train_std = train_score.std(axis=1)
test_mean = test_score.mean(axis=1)
test_std = test_score.std(axis=1)

plt.plot(param_range, train_mean, color='blue', marker='o',
         markersize=5, label='Training accuracy')
plt.fill_between(param_range,
                 train_mean + train_std,   # y1 — upper edge
                 train_mean - train_std,   # y2 — lower edge
                 alpha=0.15, color='blue')

plt.plot(param_range, test_mean, color='green', marker='*',
         markersize=5, label='test accuracy')
plt.fill_between(param_range,
                 test_mean + test_std,   # y1 — upper edge
                 test_mean - test_std,   # y2 — lower edge
                 alpha=0.15, color='green')

plt.grid()
plt.xlabel('Parameter C')
# on a linear scale, the distance between 1 to 10 is the same as between 10 and 19. 
# On a log scale, the distance between 1 and 10 is the same as between 10 and 100, and 100 and 1000. 
plt.xscale('log') 
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.ylim([0.8, 1.03])
plt.show()

# %% [markdown]
# ``cross_val_score`` — Estimates a model's generalization performance by training and scoring across multiple folds, returning per-fold scores so you see both average performance and its variance.
#
# ``StratifiedKFold`` — A cross-validation splitter that partitions data while preserving the class distribution in each fold; essential for imbalanced problems like fraud detection where random splits could leave folds with too few positives.
#
# ``learning_curve ``— Diagnoses bias vs. variance by plotting training and validation scores against increasing training set sizes, telling you whether more data would help (overfitting) or whether the model is too simple (underfitting).
#
# ``Validation curve``: diagnoses bias vs.Validation curve: diagnoses bias vs. variance by plotting training and cross-validation scores across a range of a single hyperparameter (here, C), revealing where the model underfits (both scores low), overfits (training high, validation low), or hits the sweet spot — so you can pick a good value for that hyperparameter.

# %% [markdown]
# ### Step 8: Tuning hyperparameters vias grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# chain two steps
pipe_svc = make_pipeline(StandardScaler(),
                        SVC(random_state=1))
# parameter range
param_range=[0.0001, 0.001, 0.01, 0.1,
             1.0, 10.0, 100.0, 1000.0]

# list of two dicts
# first and second dict are run separately, firts dict has 8 * 1 loops
# secodn dirct have 8 * 8 * 1 loops
# combine 8 + 64 = 72
param_grid = [{
    'svc__C': param_range, # <step_name>__<param>, double underscore
    'svc__kernel':['linear']},
    {'svc__C': param_range,
     'svc__gamma': param_range,
     'svc__kernel': ['rbf']}]

gs = GridSearchCV(estimator=pipe_svc,
                  param_grid = param_grid,
                  scoring='accuracy', # metric used to rank combinations
                  cv=10, #10-fold cross-validation, so each of the 72 combinations is fit 10 times (710 fits total)
                  refit=True, # after finding the best params, refit one final model on the entire
                  # training set. This is what mkes gs itself usable as a fitted estimator afterward
                  n_jobs=-1) # parallelize across all CPU cores
gs = gs.fit(X_train, y_train)
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.9846859903381642
# {'svc__C': 100.0, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}

# %%
# estimate the performance of the best-selected model
clf = gs.best_estimator_
clf.fit(X_train, y_train)
print('Test accuray: %.3f' % clf.score(X_test, y_test))
# Out:
# Test accuray: 0.974

# %% [markdown]
# ### Step 9: Algorithm selection with nested cross-validation
# ``Nested CV:``
# Hyperparameter tuning is itself fit to the validation data, so reporting the best CV score from a grid search is optimistically biased — you've selected on noise. Nested CV puts the hyperparameter search inside an outer CV loop, so the outer folds give you an unbiased estimate of the full pipeline's generalization performance, including the cost of the model selection step. The inner loop picks hyperparameters; the outer loop evaluates the procedure.

# %% [markdown]
# In the provided code, `cross_val_score` is being used to evaluate the **entire** model selection process, whereas `GridSearchCV` is being used to **find** the best parameters.
#
# Here is the breakdown of why they are both used together:
#
# 1.  **`GridSearchCV(cv=2)` is for Model Selection:** Its primary job is to find the best hyperparameters. It splits the training data into 2 folds to test which combination of parameters from your `param_grid` performs best. Once it finds the best parameters, it refits the model on the entire training set.
#
# 2.  **`cross_val_score(gs, ...)` is for Performance Estimation:** Even though `GridSearchCV` found the "best" parameters, the accuracy reported by `GridSearchCV` can be biased because the model was optimized specifically to perform well on those specific validation folds. By wrapping the entire `gs` object in `cross_val_score`, you are performing an **outer cross-validation**.
#
# **The Workflow in your code:**
# *   **Inner Loop (`GridSearchCV`):** "Which settings work best for this data?"
# *   **Outer Loop (`cross_val_score`):** "Now that I have the best settings, how well does this entire pipeline actually generalize to unseen data?"
#
# Using `cross_val_score` on top of `GridSearchCV` is a technique used to prevent **overfitting to the validation set** and to provide a more honest, unbiased estimate of how the model will perform on truly new data.

# %%
gs = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=2)
scores = cross_val_score(gs, X_train, y_train,
                         scoring='accuracy',
                         cv=5)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores),
                             np.std(scores)))
# Out:
# CV accuracy: 0.974 +/- 0.015

# %%
from sklearn.tree import DecisionTreeClassifier
gs = GridSearchCV(
    estimator = DecisionTreeClassifier(random_state=0),
    param_grid={
        'max_depth':[1,2,3,4,5,6,7, None]},
    scoring='accuracy',
    cv=2)
scores = cross_val_score(gs, X_train, y_train, 
                         scoring='accuracy', cv=5)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores),
np.std(scores)))
# Out:
# CV accuracy: 0.934 +/- 0.016

# %% [markdown]
# ### Step 10: Looking at different performance evaluation metrics

# %% [markdown]
# #### 1) Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
pipe_svc.fit(X_train, y_train)
y_pred = pipe_svc.predict(X_test)
confmat = confusion_matrix(y_true=y_test, y_pred=y_pred)
print(confmat)
# Out:
# [[71  1]
#  [ 2 40]]

# %%
ConfusionMatrixDisplay.from_estimator(pipe_svc, 
                                      X_test, 
                                      y_test, 
                                      display_labels=['neg','pos'], 
                                      cmap='Blues')
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(y_test, 
                                        y_pred,
                                        cmap='Blues')
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm) # can't change color
disp.plot()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.matshow(cm, cmap='Blues', alpha=0.56)
for i in range(cm.shape[1]):
    for j in range(cm.shape[0]):
        ax.text(x=j, y=i,
                s=cm[i,j],
                va='center', ha='center')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# #### 2) Optimizing the precision and recall of a classification model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
print(f'precision score: {precision_score(y_test, y_pred):.3f}')
print(f'recall score: {recall_score(y_test, y_pred):.3f}')
print(f'F1 score: {f1_score(y_test, y_pred):.3f}')
# Out:
# precision score: 0.976
# recall score: 0.952
# F1 score: 0.964

# %%
# changet he evaluation metrics and specify a different positive label
from sklearn.metrics import make_scorer, f1_score
c_gamma_range = [0.01, 0.1, 1.0, 10.0]
param_grid = [{'svc__C': c_gamma_range,
                # the kernel is the function the SVM uses to measure similarity between two data pints.
                # It's what determines the shape of the decision boundary the classifier can draw.
               'svc__kernel':['linear']}, 
               {'svc__C': c_gamma_range,
                'svc__gamma': c_gamma_range,
                'svc__kernel':['rbf']}] # radial basis function, decays with distance, it allows SVM draw curved, nonlinear boundaries
scorer = make_scorer(f1_score, pos_label=0)
gs = GridSearchCV(estimator=pipe_svc,
                  param_grid = param_grid,
                  scoring=scorer,
                  cv=10)
gs = gs.fit(X_train, y_train)
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.9861994953378878
# {'svc__C': 10.0, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}

# %% [markdown]
# #### 3) Plotting a receiver operating characteristic
# - ROC graphs are useful tools to select models for classification based on their performance with respect to the FRP and TPR, which are computated by shifign the decison threshold of the classifier.
# - The diagonal of a ROC graph can be intepreted as random gussing.
# - ``precision-recall curves`` - used for imbalance data

# %% [markdown]
# #### **ROC Curve (Receiver Operating Characteristic)**
# The ROC curve is a graphical plot that illustrates the diagnostic ability of a binary classifier system as its discrimination threshold is varied. It plots the relationship between the **True Positive Rate (TPR)** and the **False Positive Rate (FPR)**.
#
# *   **True Positive Rate (TPR) / Recall / Sensitivity:** $\frac{TP}{TP + FN}$
#     *   *Meaning:* The probability that a true positive is correctly identified.
# *   **False Positive Rate (FPR) / Fall-out:** $\frac{FP}{FP + TN}$
#     *   *Meaning:* The probability that a negative instance is incorrectly classified as positive.
#
# **How to interpret the curve:**
# *   The x-axis represents the FPR, and the y-axis represents the TPR.
# *   A **perfect classifier** follows the left-hand corner (FPR=0, TPR=1).
# *   A **random classifier** follows a diagonal line from (0,0) to (1,1), representing a 50% chance of being correct.
#
#
# #### **ROC AUC Score**
# The **AUC (Area Under the Curve)** is a single scalar value that summarizes the ROC curve. It represents the probability that the model will rank a randomly chosen positive instance higher than a randomly chosen negative instance.
#
# *   **AUC = 1.0:** A perfect model (zero errors).
# *   **AUC = 0.5:** A useless model (equivalent to random guessing/flipping a coin).
# *   **AUC < 0.5:** The model is performing worse than random guessing (it is consistently predicting the wrong class; in this case, simply inverting the predictions would improve it).
#
# **Key Characteristics:**
# *   **Threshold-Invariant:** Unlike accuracy or F1-score, which depend on a specific classification threshold (e.g., 0.5), AUC measures performance across **all possible thresholds**.
# *   **Scale-Invariant:** It measures how well predictions are ranked rather than their absolute values.
#
# ---
#
# #### **Comparison Summary**
#
# | Feature | **ROC Curve** | **ROC AUC Score** |
# | :--- | :--- | :--- |
# | **Type** | Visual Plot (Graph) | Numerical Metric (Scalar) |
# | **Purpose** | To visualize the trade-off between TPR and FPR at various thresholds. | To provide a single number to compare different models. |
# | **Use Case** | To decide the optimal threshold for a specific business requirement (e.g., minimizing False Positives). | To rank and select the best performing model during development. |
# | **Output** | A line/curve. | A value between 0 and 1 (usually). |
#
# #### **Implementation Example (Python/Scikit-Learn)**
# ```python
# from sklearn.metrics import roc_curve, roc_auc_score
#
# # y_true: actual labels (0 or 1)
# # y_scores: predicted probabilities (e.g., 0.85, 0.12, etc.)
#
# # 1. Calculate AUC Score
# auc = roc_auc_score(y_true, y_scores)
#
# # 2. Calculate ROC Curve coordinates
# fpr, tpr, thresholds = roc_curve(y_true, y_scores)
#
# print(f"AUC Score: {auc}")
# ```

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc
pred_prob = pipe_lr.fit(X_train, y_train).predict_proba(X_train)[:,1]
fpr, tpr, threshold = roc_curve(y_train, pred_prob)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f'ROC (area = {roc_auc:.3f})')
plt.plot((0,1), (0,1), 'k--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### 4) Scoring metrics fro multiclass classification

# %% [markdown]
# #### 5) Dealing with class imbalance

# %%
# pull y==0 with 357 samples, but y==1 only 40 samples
X_imb = np.vstack((X[y==0], X[y==1][:40]))
y_imb = np.hstack((y[y==0], y[y==1][:40]))

# %%
# if we predict all 0s
y_pred = np.zeros(y_imb.shape[0])
np.mean(y_pred==y_imb)*100
# Out:
# np.float64(89.92443324937027)

# %%
from sklearn.utils import resample
print('Number of class 1 examples before: ', X_imb[y_imb==1].shape[0])
X_upsampled, y_upsampled = resample(
    X_imb[y_imb==1],
    y_imb[y_imb==1],
    replace=True,
    n_samples=X_imb[y_imb==0].shape[0],
    random_state=123
)
print('Number of class 1 examples after:',
      X_upsampled.shape[0])

X_bal = np.vstack((X[y==0], X_upsampled))
y_bal = np.hstack((y[y==0], y_upsampled))

y_pred = np.zeros(y_bal.shape[0])
np.mean(y_pred==y_bal) * 100
# Out:
# Number of class 1 examples before:  40
# Number of class 1 examples after: 357
# np.float64(50.0)
